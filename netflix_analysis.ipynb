# %%
import numpy as np
import pandas as pd

from plotly import graph_objs as go

import plotly.express as px
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

netflix = pd.read_csv('C:/Users/lap/Downloads/netflix_titles_nov_2019.csv')
print(netflix.head(5))

netflix['season_count'] = netflix.apply( lambda x : x['duration'].split(" ")[0]
                                         if "Season" in x['duration'] else " ", axis = 1)
#print(netflix.head())

group_netflix = netflix.type.value_counts()
#print(group_netflix)
trace = go.Pie(labels = group_netflix.index,values =
              group_netflix.values, pull = [0.05])

layout = go.Layout(title = "TV Shows VS Movies",
                  height= 400, legend = dict(x=1.1, y=1.3))



netflix["date_added"] = pd.to_datetime(netflix['date_added'])
netflix['year_added'] = netflix['date_added'].dt.year

netflix["date_added"] = pd.to_datetime(netflix['date_added'])
netflix['year_added'] = netflix['date_added'].dt.year


movie_per_year=[]

tv_shows_per_year=[]
for i in range(2010,2020):
    h=netflix.loc[(netflix['type']=='Movie') & (netflix.year_added==i)]
    #print (h)
    g=netflix.loc[(netflix['type']=='TV Show') & (netflix.year_added==i)]
    #print (g)
    movie_per_year.append(len(h))
    print (movie_per_year)
    tv_shows_per_year.append(len(g))
# Out:
#     show_id                                title                    director  \
# 0  81193313                            Chocolate                         NaN
# 1  81197050  Guatemala: Heart of the Mayan World  Luis Ara, Ignacio Jaunsolo
# 2  81213894                      The Zoya Factor             Abhishek Sharma
# 3  81082007                            Atlantics                   Mati Diop
# 4  80213643                      Chip and Potato                         NaN
#
#                                                 cast  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                  Christian Morales
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4  Abigail Oliver, Andrea Libman, Briana Buckmast...
#
#                     country         date_added  release_year rating  \
# 0               South Korea  November 30, 2019          2019  TV-14
# ...
